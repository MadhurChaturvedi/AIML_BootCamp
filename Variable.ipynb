# %%
## Varables
a=100

# %%
#declaromg amd Assiging varable 

age=25
name="Madhur Chaturvedi"
isStudent=True
height=5.11

#Print
print("Name:",name)
print("Age:",age)       
print("Is Student:",isStudent)
print("Height:",height)
# Out:
# Name: Madhur Chaturvedi
# Age: 25
# Is Student: True
# Height: 5.11

# %%
age = 23
age_str = str(age)
print("Updated Age:", age_str)
print("Data type of age_str:", type(age_str))

sore="50"
score_int=int(sore)
print("Score as integer:",score_int)
print("Data type of score_int:", type(score_int))
# Out:
# Updated Age: 23
# Data type of age_str: <class 'str'>
# Score as integer: 50
# Data type of score_int: <class 'int'>

# %%
## python allows the type of a variable as the program executes
# var = 10
# print(var,type(var))

a = input("Enter you name: ")
print("Hello,", a)
# Out:
# Hello, Madhur
