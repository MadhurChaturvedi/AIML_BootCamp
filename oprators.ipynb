# %%
## everthing +,-,/,*,%  it double diveide // means
a=10
b=5
result = a//b
print(result)

print(a%b)
print(3%5)
# exponential opration

new_result = a ** b
print(new_result)
# Out:
# 2
# 0
# 3
# 100000

# %%
## comparsion oprator
## == 
a=10
b=10
print(a==b)


str1="madhur"
str2="Madhur"
print(str1==str2)
# Out:
# True
# False

# %%
num1 = 10
num2 = 89

if num1==10 and num2==20:
    print(True)
else:
    print(False)


if num1==10 or num2==20:
    print(True)
else:
    print(False)    


if not num1>num2:
    print(True)
else:
    print(False)
# Out:
# False
# True
# True
