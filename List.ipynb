# %%
elements = [1,2,3,4,5]

elements.append(10)

# elements.reverse()

# for i in elements:
#     if i == 3:
#         # sorry it will remove last element 
#         elements.pop()

# for i in elements:
#     print(i, end=" ")        




def Index(elemnt, elements):
    int(elemnt)
    for i in elements:
        if i == elemnt:
          return elements.index(i)
Index(10,elements)

# this how we indexing linearserach

# print(result)
# Out:
# 5

# %%
##Basic List comprehsion
square = [num**2 for num in  range(10)]
print(square)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
even_nubmber = [num for num in range(10) if num%2==0]
print(even_nubmber)
# Out:
# [0, 2, 4, 6, 8]
