# %%
## use the for loop and range ther 3 type is paramater if riang were we can pass the paramter last on otional if we want to escape an keyword

# for i in range(1,10):
#     # print(i)

# for i in range(1,10,2):
#     print(i)

# %%
# While Loop
cout=0
while cout<5:
    print(cout)
    cout=cout+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# containe and for loop example
user=input("Enter a Number")
int_type_user = int(user)
for i in range (1,int_type_user):
    if i == 5:
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9

# %%
#pass
for i in range(5):
    if i == 3:
        pass
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#nested loop

for i in range(3):
    for j in range(2):
        print(f"i:{i} and j:{j}")
# Out:
# i:0 and j:0
# i:0 and j:1
# i:1 and j:0
# i:1 and j:1
# i:2 and j:0
# i:2 and j:1

# %%
n=10
sum=0
count=1

while count<=n:
    sum = sum+count
    count=count+1

print("Sum of Naturel numebr : ",sum )
# Out:
# Sum of Naturel numebr :  55
